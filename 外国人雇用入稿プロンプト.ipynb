# %% [markdown]
# <a href="https://colab.research.google.com/github/seripoyo/wp-prompt/blob/main/%E5%A4%96%E5%9B%BD%E4%BA%BA%E9%9B%87%E7%94%A8%E5%85%A5%E7%A8%BF%E3%83%97%E3%83%AD%E3%83%B3%E3%83%97%E3%83%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 必要なライブラリをインストールします
# !pip install markdown -q

import re
import markdown
import json
import os
from google.colab import files
from IPython.display import display, HTML

# -------------------------------------------------------------------
# 変換ロジックの関数
# -------------------------------------------------------------------
def convert_specific_md_to_html(md_text):
    """
    特定のルールに基づいてマークダウンテキストをHTMLに変換する関数。
    """
    processed_text = md_text

    # --- ステップ1: ブロックレベルのカスタム構文を先にHTMLに置換 ---
    def replace_freebox(match):
        title = match.group(1).strip()
        content = match.group(2).strip()
        content_html = markdown.markdown(content, extensions=['tables'])
        return (f'<div style="padding: 10px 0;">\n'
                f'<div class="freebox"><p class="p-free"><span class="p-entry-f">{title}</span></p><div class="free-inbox">{content_html}</div></div></div>')
    processed_text = re.sub(r'^★\*\*(.*?)\*\*\s*([\s\S]*?)\s*★$', replace_freebox, processed_text, flags=re.MULTILINE)

    # ★★★ [ ] や ■ ■ で囲まれたブロックをテーブルに変換するロジック ★★★
    def replace_block_with_styled_table(match):
        content = match.group(1).strip()

        # コンテンツを段落（空行区切り）で分割し、空の要素は除去
        paragraphs = [p.strip() for p in re.split(r'\n\s*\n', content) if p.strip()]

        if not paragraphs:
            return ""

        processed_paragraphs = []
        for para in paragraphs:
            # **...** でテキストを分割する。キャプチャグループ `()` を使うことで、
            # デリミタ自体も結果のリストに含まれるようにする。
            parts = re.split(r'(\*\*.*?\*\*)', para)

            processed_para_parts = []
            for part in parts:
                # 空の文字列はスキップ
                if not part:
                    continue

                # テキスト内の改行を <br /> に変換
                part_with_br = part.replace('\n', '<br />\n')

                # partが **...** の形式かチェック
                if part.startswith('**') and part.endswith('**'):
                    # ** を取り除いた部分のテキストを取得
                    inner_text_with_br = part_with_br[2:-2]
                    processed_para_parts.append(f'<strong>{inner_text_with_br}</strong>')
                else:
                    # 太字でない部分はspanで囲む
                    processed_para_parts.append(f'<span style="font-weight: 400;">{part_with_br}</span>')

            # 1つの段落を構成するHTMLパーツを結合
            processed_paragraphs.append(''.join(processed_para_parts))

        # 処理済みの各段落を改行文字で結合
        content_html = '\n'.join(processed_paragraphs)

        return (f'<table style="border-collapse: collapse; width: 100%;">\n'
                f'<tbody>\n'
                f'<tr><td style="width: 100%;">\n{content_html}\n</td>\n'
                f'</tr>\n'
                f'</tbody>\n'
                f'</table>')

    # [ ... ] のブロックを処理
    processed_text = re.sub(r'^\[\s*?$([\s\S]*?)^\]\s*?$', replace_block_with_styled_table, processed_text, flags=re.MULTILINE)

    # ■ ... ■ のブロックを処理（同じ関数を再利用）
    processed_text = re.sub(r'^■\s*?$([\s\S]*?)^■\s*?$', replace_block_with_styled_table, processed_text, flags=re.MULTILINE)


    # --- ステップ2: インラインのカスタム構文や単純なショートコード置換 ---
    processed_text = processed_text.replace("【目次】", "[toc]")
    processed_text = processed_text.replace("【山根さん監修】", "[sc name=\"yamane_kansyu\"][/sc]")
    processed_text = processed_text.replace("【特定技能外国人の受入れ診断チェック】", "[sc name=\"sindancheck\"][/sc]")
    processed_text = processed_text.replace("【最終CTA】", "[sc name=\"last_cta\"][/sc]")

    # --- ステップ3: リンクにtarget="_blank"を追加するための前処理 ---
    processed_text = re.sub(r'^(参考：\s*)(\[.*?\]\(.*?\))', r'\1\2{:target="_blank" rel="noopener"}', processed_text, flags=re.MULTILINE)

    # --- ステップ4: 標準MarkdownからHTMLへの変換 ---
    html = markdown.markdown(processed_text, extensions=['tables', 'attr_list'])

    # --- ステップ5: HTMLに対する後処理 ---
    def style_table_header(match):
        thead_content = match.group(1)
        styled_thead_content = re.sub(r'<th>', '<th style="background-color: #f0f0f0; font-weight: bold;">', thead_content)
        return f'<thead>{styled_thead_content}</thead>'
    html = re.sub(r'<thead>([\s\S]*?)</thead>', style_table_header, html)

    h2_count = 0
    def replace_h2(match):
        nonlocal h2_count
        h2_count += 1
        content = match.group(1)
        tag_id = "i" if h2_count == 1 else f"i-{h2_count}"
        return f'<h2><span id="{tag_id}"></span>{content}</h2>'

    h3_count = 0
    def replace_h3(match):
        nonlocal h3_count
        h3_count += 1
        content = match.group(1)
        tag_id = "i-2" if h3_count == 1 else f"i-2-{h3_count}"
        return f'<h3><span id="{tag_id}"></span>{content}</h3>'

    html = re.sub(r'<h2>(.*?)</h2>', replace_h2, html)
    html = re.sub(r'<h3>(.*?)</h3>', replace_h3, html)

    def add_target_to_related_links(match):
        section_html = match.group(0)
        return re.sub(r'<a href="', '<a target="_blank" rel="noopener" href="', section_html)
    html = re.sub(r'(<h[1-6]>【関連記事】</h[1-6]>\s*<ul>[\s\S]*?</ul>)', add_target_to_related_links, html)

    return html

# -------------------------------------------------------------------
# メインの実行部分
# -------------------------------------------------------------------
def main():
    """アップロードされたMDファイルを探して変換処理を実行する"""
    markdown_file_name = None
    search_directory = '/content/'

    for filename in os.listdir(search_directory):
        if filename.endswith('.md'):
            markdown_file_name = filename
            break

    if markdown_file_name:
        print(f"✅ マークダウンファイル '{markdown_file_name}' を検出しました。変換処理を開始します...")
        file_path = os.path.join(search_directory, markdown_file_name)

        with open(file_path, 'r', encoding='utf-8') as f:
            md_content = f.read()

        html_output = convert_specific_md_to_html(md_content)

        # --- 結果の表示とコピーボタンの実装 ---
        escaped_html = json.dumps(html_output)
        display_code = f"""
        <h4>変換後のHTML</h4>
        <textarea id="html-output" style="width: 95%; height: 250px; font-family: monospace; border: 1px solid #ccc; padding: 5px;" readonly>{html_output}</textarea>
        <br>
        <button onclick="copyToClipboard()" style="padding: 8px 15px; border-radius: 5px; background-color: #4CAF50; color: white; border: none; cursor: pointer;">
          クリップボードにコピー
        </button>
        <span id="copy-status" style="margin-left: 10px; color: green; font-weight: bold;"></span>

        <script>
        function copyToClipboard() {{
            const textToCopy = {escaped_html};
            navigator.clipboard.writeText(textToCopy).then(() => {{
                const status = document.getElementById('copy-status');
                status.textContent = 'コピーしました！';
                setTimeout(() => {{ status.textContent = ''; }}, 2000);
            }}).catch(err => {{
                console.error('コピーに失敗しました: ', err);
                const status = document.getElementById('copy-status');
                status.textContent = 'コピーに失敗しました。';
                setTimeout(() => {{ status.textContent = ''; }}, 2000);
            }});
        }}
        </script>
        """
        display(HTML(display_code))

    else:
        print("⚠️ マークダウンファイルが見つかりませんでした。")
        print("左側のファイルパネルに .md ファイルをアップロードしてから、このセルを再度実行してください。")

# スクリプトを実行
main()
# Out:
# ✅ マークダウンファイル '外国人のプロンプト用原稿サンプル 02.md' を検出しました。変換処理を開始します...
#         <h4>変換後のHTML</h4>
#         <textarea id="html-output" style="width: 95%; height: 250px; font-family: monospace; border: 1px solid #ccc; padding: 5px;" readonly><p>ネパール人の従業員を雇用しようとお考えのみなさま、彼らの文化的背景や生活習慣についてどのくらいご存知でしょうか？</p>
# <p>外国人労働者の受け入れにあたっては、言葉の壁や価値観の違いなど、さまざまな課題に直面することがあります。</p>
# <p>この記事では、ネパール人の性格的特徴や考え方から、宗教上のタブーまで、彼らを理解するためのポイントを幅広く解説します。</p>
# <p>弊社「<a href="https://gaikokusaiyo.com/">外国人採用の窓口</a>」では、<strong>技能実習生の雇用に関する相談を無料で</strong>受け付けております。お悩み・聞きたいことがある方は、以下の問い合わせフォームまたは電話にてお気軽にお問い合わせください。</p>
# <p>[toc]</p>
# <p>[sc name="yamane_kansyu"][/sc]</p>
# <h2><span id="i"></span>ネパール人の特徴と価値観</h2>
# <p>ネパール人と働く際に、彼らの文化的背景や価値観を理解しておくことは非常に重要です。</p>
# <p>ここでは、ネパール人の性格的特徴、文化的背景、コミュニケーションスタイル、そして宗教とタブーについて詳しく見ていきましょう。</p>
# <h3><span id="i-2"></span><strong>ネパール人の性格的特徴</strong></h3>
# <p>ネパール人は一般的に素直で控えめな性格をしています。</p>
# <p>日本への憧れが強く、指示を素直に聞く傾向があります。初めは遠慮がちですが、親しくなると積極的になるのが特徴です。</p>
# <p>また、ネパール人は我慢強く、文句を言うことが少ないと言われています。これは、ネパール国内の厳しい労働環境に慣れていることや、歴史的背景から耐える力が強いためだと考えられます。</p>
# <p>しかし、日本人から見ると大雑把な面もあります。時間にルーズであったり、片付けを後回しにする傾向があったりします。物をよく無くしたり、約束を忘れがちだったりすることもあるでしょう。</p>
# <p>さらに、ネパール人の中には向上心が低い人が多いと言われています。</p>
# <p>これは、カースト制度の影響が残っていることや、現状を受け入れる傾向があることが理由として挙げられます。</p>
# <p>在留資格は<strong>実習期間や技能レベルに応じて「技能実習1号」「技能実習2号」「技能実習3号」</strong>に分かれています。在留資格の違いを以下の表にまとめました。</p>
# <table>
# <thead>
# <tr>
# <th style="background-color: #f0f0f0; font-weight: bold;"></th>
# <th style="background-color: #f0f0f0; font-weight: bold;">在留期間</th>
# <th style="background-color: #f0f0f0; font-weight: bold;">対象職種</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>技能実習1号</td>
# <td>1年間</td>
# <td>制限なし ※技能実習2号に移行するには移行対象職種と同一の職種である必要がある</td>
# </tr>
# <tr>
# <td>技能実習2号</td>
# <td>2年間</td>
# <td>91職種168作業</td>
# </tr>
# <tr>
# <td>技能実習3号</td>
# <td>2年間</td>
# <td>技能実習２号移行対象職種と同一（技能実習３号が整備されていない職種を除く。）</td>
# </tr>
# </tbody>
# </table>
# <p>参考：<a href="https://share.google/FbVjsJktbLiwRapzE" rel="noopener" target="_blank">技能実習制度 移行対象職種・作業一覧</a>│厚生労働省<br />
# 参考：<a href="https://www.mhlw.go.jp/content/001336196.pdf" rel="noopener" target="_blank">外国人技能実習制度について（令和7年4月1日改定版）</a>│厚生労働省</p>
# <h3><span id="i-2-2"></span><strong>ネパール人の文化的背景と価値観</strong></h3>
# <p>ネパール人は、年長者や高齢者を大切にする文化を持っています。</p>
# <p>また、異なる文化や考えに対して寛容であることも特徴の一つです。助け合いの精神が強く、困っている人がいれば進んで手助けをするでしょう。</p>
# <p>ネパールの教育水準は上昇傾向にありますが、まだ日本と比較すると低い状況です。</p>
# <p>小学校の最終学年までの継続率は74％、中学校への進学率は86％、識字率は71％となっています。ただし、英語を話せる人は増加傾向にあります。</p>
# <h3><span id="i-2-3"></span><strong>ネパール人の宗教とタブー</strong></h3>
# <p>ネパールの主要な宗教はヒンドゥー教とチベット仏教です。</p>
# <p>多くのネパール人は宗教的信仰が厚く、日常生活の中で宗教的慣習を大切にしています。</p>
# <p>ネパール人にとってのタブーとしては、<strong>牛肉を食べることや、左手で物を渡すこと、頭を触ること</strong>などが挙げられます。また、<strong>公の場で宗教や政治について議論することは避けた方が良いでしょう。</strong></p>
# <p>ネパール人と働く際は、彼らの宗教的信念を尊重し、タブーに触れないように注意することが重要です。</p>
# <p>宗教的な慣習や祝日には配慮を欠かさないようにしましょう。</p>
# <h2><span id="i-2"></span>ネパール人の教育と技能</h2>
# <h3><span id="i-2-4"></span><strong>ネパール人の一般的な技能レベル</strong></h3>
# <p>次に、ネパール人の一般的な技能レベルについて見ていきます。</p>
# <p>ネパールでは、職業訓練校や専門学校などで技能を学ぶ機会が限られているため、全体的な技能レベルは高くありません。</p>
# <p>しかし、ネパール人は勤勉で向上心があり、丁寧に仕事を教えれば着実に技能を身につけていきます。特に、繰り返しの作業や単純作業には適性があると言えるでしょう。</p>
# <p>また、ネパールでは英語教育が普及しており、英語を話せる人材が増加傾向にあります。</p>
# <p>コミュニケーション能力の高さは、ネパール人労働者の強みの一つと言えます。</p>
# <h3><span id="i-2-5"></span><strong>ネパール人が得意とする職種・分野</strong></h3>
# <p>ネパール人が得意とする職種・分野としては、以下のようなものが挙げられます。</p>
# <ul>
# <li>製造業（自動車部品、電子部品など）  </li>
# <li>建設業  </li>
# <li>農業・畜産業  </li>
# <li>介護・看護  </li>
# <li>ホテル・レストランサービス</li>
# </ul>
# <p>特に、製造業や建設業では、ネパール人労働者の真面目で勤勉な性格が活かされています。また、ネパール国内で農業に従事していた人も多いため、農業・畜産業での活躍も期待できるでしょう。</p>
# <p>介護・看護の分野では、ネパール人のもつ思いやりと優しさが強みとなります。</p>
# <p>ホテル・レストランサービスでは、ネパール人の持ち前の明るさと親切さが発揮されています。</p>
# <table style="border-collapse: collapse; width: 100%;">
# <tbody>
# <tr><td style="width: 100%;">
# <span style="font-weight: 400;">①監理・指導</span>
# <span style="font-weight: 400;">監理団体の許可基準に基づき、実習実施者に対する技能実習状況の確認や指導をおこないます。</span>
# <span style="font-weight: 400;">技能実習制度はさまざまな法令を守りながら適切に進めなくてはなりません。</span>
# </td>
# </tr>
# </tbody>
# </table>
#
# <p>専門的知識をもち、多様な立場の人や団体とコミュニケーションをとり、適切な指導と監理をおこなう役目があります。</p>
# <h2><span id="i-3"></span>ネパール人が日本で働く理由と動機</h2>
# <p>ネパール人が日本で働く背景には、ネパール国内の経済状況や就労環境が深く関わっています。</p>
# <p>ここでは、ネパール人が日本で働く理由と動機について詳しく見ていきましょう。</p>
# <h3><span id="i-2-6"></span><strong>ネパールの経済状況と就労事情</strong></h3>
# <p>ネパールは、1人当たりのGDPが1,336米ドル（2022年度）と、経済的に発展途上にある国の一つです。</p>
# <p>一方、日本の1人当たりGDPは33,815米ドルと、ネパールの約25倍の水準にあります。</p>
# <p>また、ネパール国内の就労環境は厳しく、十分な収入を得ることが難しい状況にあります。</p>
# <p>こうした経済的な理由から、多くのネパール人が海外での就労を求めているのです。</p>
# <h3><span id="i-2-7"></span><strong>日本で働くネパール人の主な目的</strong></h3>
# <p>ネパール人が日本で働く主な目的は、<strong>高収入を得ること</strong>です。</p>
# <p>日本の労働環境は、ネパールと比べて非常に恵まれており、同じ仕事をしても数倍の収入を得ることができます。</p>
# <p>また、日本は治安が良く、労働環境も整っているため、安心して働くことができる点も大きな魅力となっています。</p>
# <p>特に単純労働の分野では、ネパール人労働者にとって働きやすい環境が整っています。</p>
# <p>技能実習2号へ移行するためには、以下2つの条件を満たす必要があります。</p>
# <div style="padding: 10px 0;">
# <div class="freebox"><p class="p-free"><span class="p-entry-f">技能実習2号へ移行する条件</span></p><div class="free-inbox"><p>1）技能検定「基礎級」の学科試験と実技試験に合格する</p>
# <p>2）技能実習2号でおこなう作業が、移行対象職種・作業である</p></div></div></div>
#
# <p>技能実習2号でおこなう作業が、移行対象職種・作業である技能実習生は、1号の技能実習開始から8～9ヵ月目に<strong>技能検定「基礎級」を受験し、学科試験と実技試験の両方に合格する必要</strong>があります。</p>
# <p>試験合格や対象職種の条件を満たし、外国人技能実習機構での<strong>2号技能実習計画の認定、出入国在留管理庁での在留資格変更許可</strong>が下りると技能実習2号へ移行できます。</p>
# <h3><span id="i-2-8"></span><strong>ネパール人が日本企業に求めるもの</strong></h3>
# <p>ネパール人労働者が日本の企業に求めるものは、<strong>安定した雇用と適正な労働環境</strong>です。</p>
# <p>日本企業に就職することで、長期的に安定した収入を得ることができると考えています。</p>
# <p>また、ネパールと日本では文化や習慣が大きく異なるため、日本の企業文化や労働慣行について丁寧な説明と教育を受けられることを期待しています。</p>
# <p>これにより、スムーズに日本の職場に適応し、能力を発揮できると考えているのです。</p>
# <p>日本企業がネパール人労働者を採用する際は、彼らの目的や期待を理解し、適切な環境を整備することが重要となります。</p>
# <p>異文化コミュニケーションや日本の労働慣行についての教育に力を入れることで、ネパール人労働者が能力を最大限に発揮できる職場づくりが可能となるでしょう。</p>
# <h2><span id="i-4"></span>ネパール人雇用のメリット</h2>
# <p>ネパールから来日する外国人労働者の採用は、日本企業にとってさまざまな恩恵をもたらします。</p>
# <p>ここでは、ネパール人を雇用することで得られる主要なメリットについて解説していきましょう。</p>
# <h3><span id="i-2-9"></span><strong>勤勉で真面目な働きぶり</strong></h3>
# <p>ネパール人労働者の大きな特徴として、勤勉で真面目な働きぶりが挙げられます。</p>
# <p>彼らの多くは、日本社会への憧れを抱いており、与えられた仕事に対して真摯に取り組む姿勢を示します。</p>
# <p>その背景には、ネパール国内における厳しい労働環境があります。</p>
# <p>長時間労働や過酷な条件下での仕事に慣れているため、日本の職場環境では比較的高い適応力を発揮します。また、歴史的な背景から培われた我慢強さも、彼らの仕事ぶりに反映されています。</p>
# <p>ただし、時間管理や整理整頓などの面では、日本人の感覚とは異なる部分もあるため、適切な指導と教育が必要となるでしょう。しかし、全体的には<strong>真面目で献身的な働きぶり</strong>が期待できます。</p>
# <h3><span id="i-2-10"></span><strong>長期就労が見込める</strong></h3>
# <p>ネパール人労働者を雇用するもう一つの利点は、長期的な就労が見込めることです。</p>
# <p>彼らの多くは、日本で安定した収入を得ることを目的としており、短期的な滞在ではなく、可能な限り長く働くことを望んでいます。</p>
# <p>これは、ネパールと日本の経済水準の差が大きいことに起因しています。</p>
# <p>2022年度のデータによると、ネパールの1人当たりGDPは1,336米ドルであるのに対し、日本は33,815米ドルと約25倍の差があります。日本で働くことで得られる高い収入は、ネパール人労働者にとって大きな魅力となっているのです。</p>
# <p>さらに、日本の治安の良さや整った労働環境も、彼らが長期滞在を希望する理由の一つです。</p>
# <p><strong>安定した雇用関係を築くことで、企業の人材不足の解消に寄与</strong>することが期待できるでしょう。</p>
# <h3><span id="i-2-11"></span><strong>人手不足の解消に貢献</strong></h3>
# <p>少子高齢化が進む日本において、深刻な人手不足は多くの企業が直面する課題です。</p>
# <p>特に、製造業や介護業界などでは、慢性的な人材不足が業務の継続や発展の妨げとなっています。こうした状況下で、ネパール人労働者の採用は、人手不足の解消に大きく貢献します。</p>
# <p>ネパール人労働者の多くは、比較的単純な作業でも真摯に取り組む姿勢を持っています。</p>
# <p>日本語能力の向上とともに、幅広い業務で即戦力として活躍することが期待できます。特に、特定技能制度の活用により、一定の日本語能力と技能を有するネパール人材の採用が可能となっています。</p>
# <p>人手不足に悩む企業にとって、ネパール人労働者の存在は、<strong>貴重な戦力となり得る</strong>のです。</p>
# <p>適切な教育と職場環境の整備を行うことで、彼らの力を最大限に引き出すことができるでしょう。</p>
# <h3><span id="i-2-12"></span><strong>技能実習3号と特定技能1号の違い</strong></h3>
# <p>技能実習3号と特定技能1号の違いとは、制度の目的や立場です。</p>
# <p>技能実習3号は、外国人技能実習制度において、最大2年間、指定された職種・作業を母国の発展のために学びます。</p>
# <p>特定技能1号は、特定技能制度において、<strong>通算5年間、指定された分野で労働者の一員として働きます</strong>。</p>
# <p>要求される技術水準は、技能実習3号より特定技能1号の方が高いです。</p>
# <p>具体的に、<strong>該当分野での知識または経験を必要とする技能を習得や日本語能力試験（Ｎ４以上）の合格</strong>など、現場で即戦力として活躍できるレベルが求められます。</p>
# <p>参考：<a href="https://share.google/pQPLUL2KFy8Rm2BC7" rel="noopener" target="_blank">特定技能 ガイドブック</a>│法務省</p>
# <p>外国人採用の窓口では「<a href="https://gaikokusaiyo.com/specified-skilled-worker-recruitment-guide/">特定技能外国人採用ガイド</a>」の資料を無料配布しております。30秒でダウンロードできますので、以下をクリックの上、どうぞお受け取りください。</p>
# <p>[sc name="sindancheck"][/sc]</p>
# <h2><span id="i-5"></span>ネパール人雇用の注意点と課題</h2>
# <h3><span id="i-2-13"></span><strong>文化や習慣の違いによる誤解やトラブル</strong></h3>
# <p>ネパール人を雇用する際、文化や習慣の違いから生じる誤解やトラブルに注意が必要です。</p>
# <p>ネパールと日本では、価値観や行動様式に大きな違いがあります。</p>
# <p>例えば、ネパール人は<strong>年長者や高齢者を大切にする文化</strong>があります。</p>
# <p>一方、日本では年功序列が崩れつつあり、若手の意見も尊重される傾向にあります。</
